# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

players = pd.read_csv('/content/drive/MyDrive/datasets/players_cleaned_of_mobile_game_inapp_purchases.csv')
purchases = pd.read_csv('/content/drive/MyDrive/datasets/purchase_cleaned.csv')

print("Players loaded:", players.shape)
print("Purchases loaded:", purchases.shape)
# Out:
# Players loaded: (3024, 18)
# Purchases loaded: (2887, 10)

# %%
print(players.isnull().sum())
# Out:
# player_id                              0
# age                                   60
# gender                                 0
# country                               60
# device                                60
# game_genre                            60
# session_count                          0
# avg_session_length                     0
# total_play_mins                        0
# spending_segment                       0
# in_app_purchase_amount                 0
# first_purchase_days_after_install    136
# payment_method                       136
# last_purchase_date                   136
# is_purchaser                           0
# days_to_first_pay                    136
# is_outlier_age                         0
# data_version                           0
# dtype: int64

# %%
print(players['is_outlier_age'].value_counts())
# Out:
# is_outlier_age
# False    2964
# True       60
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

missing = players.isnull().sum()
missing = missing[missing > 0]

plt.figure(figsize=(10,5))
missing.sort_values().plot(kind='bar')

plt.title('Missing Values by Variable')
plt.xlabel('Variables')
plt.ylabel('Number of Missing Values')

plt.show()
